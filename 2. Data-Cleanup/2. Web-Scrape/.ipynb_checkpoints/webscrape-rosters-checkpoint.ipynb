# %% [markdown]
# # Web Scraping Rosters

# %% [markdown]
# ## Setup Environment

# %%
import requests
import lxml.html as lh
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %% [markdown]
# ## Create Team List

# %%
# Team list
team_ls = ['Arizona Cardinals','Atlanta Falcons','Baltimore Ravens','Buffalo Bills','Carolina Panthers','Chicago Bears','Cincinnati Bengals',
           'Cleveland Browns','Dallas Cowboys','Denver Broncos','Detroit Lions','Green Bay Packers','Houston Texans','Indianapolis Colts',
           'Jacksonville Jaguars','Kansas City Chiefs','Las Vegas Raiders','Los Angeles Chargers','Los Angeles Rams','Miami Dolphins','Minnesota Vikings','New England Patriots',
           'New Orleans Saints','New York Giants','New York Jets','Philadelphia Eagles','Pittsburgh Steelers','San Francisco 49ers','Seattle Seahawks',
           'Tampa Bay Buccaneers','Tennessee Titans','Washington Redskins']

# Format list for URL
team_ls = [team.lower().replace(' ','-') for team in team_ls]

# %% [markdown]
# ## Create Year-Toggle Function

# %%
# Changes the year parameter on a given pages
def next_year(driver, year_idx):
    
    driver.find_element_by_xpath('//*[@id="main-dropdown"]').click()
    parentElement = driver.find_element_by_xpath('/html/body/app-root/app-nfl/app-roster/div/div/div[2]/div/div/div[1]/div/div/div')
    elementList = parentElement.find_elements_by_tag_name("button")
    elementList[year_idx].click()
    time.sleep(3)

# %% [markdown]
# ## Create Scraping Function

# %%
# Create scraping function
def sel_scrape(driver, team, year):
    
    # Get main table
    main_table = driver.find_element_by_tag_name('table')
    
    # Scrape rows and header
    rows = [[td.text.strip() for td in row.find_elements_by_xpath(".//td")] for row in main_table.find_elements_by_xpath(".//tr")][1:]
    header = [[th.text.strip() for th in row.find_elements_by_xpath(".//th")] for row in main_table.find_elements_by_xpath(".//tr")][0]
    
    # compile in dataframe
    df=pd.DataFrame(rows,columns=header)
    
    # Edit data frame
    df['Merge Name'] = df['Name'].str.split(' ',1).str[0].str[0] + '.' + df['Name'].str.split(' ').str[1]
    df['Team'] = team.replace('-',' ').title()
    df['Year'] = year
    
    return df

# %% [markdown]
# ## Run Script

# %%
if __main__ =='__name__':
    
    # Initialize basic objects needed: url, df and year list
    url='https://www.lineups.com/nfl/roster/'
    df = pd.DataFrame()
    years = [2020,2019,2018,2017]

    # Keep track of run time    
    start_time = time.time()
    
    # For every team in the list
    for team in team_ls:
        
        # Open the link
        driver = webdriver.Chrome()
        driver.get(url+team)

        # For each of the four years
        for idx in range(0,4):
            
            print("Starting {} {}".format(team, years[idx]))
            
            # Scrape the page
            df = pd.concat([df, sel_scrape(driver, team, years[idx])])

            # Change to next year
            next_year(driver, idx)
            
        driver. close()

    print("--- %s seconds ---" % (time.time() - start_time))
    
    # Export csv
    df.to_csv('../../1. Raw-Data/nfl-roster.csv', index=False)
# Out:
# 1592946784.8835697
# Starting arizona-cardinals 2020
# Starting arizona-cardinals 2019
# Starting arizona-cardinals 2018
# Starting arizona-cardinals 2017
# Starting atlanta-falcons 2020
# Starting atlanta-falcons 2019
# Starting atlanta-falcons 2018
# Starting atlanta-falcons 2017
# Starting baltimore-ravens 2020
# Starting baltimore-ravens 2019
# Starting baltimore-ravens 2018
# Starting baltimore-ravens 2017
# Starting buffalo-bills 2020
# Starting buffalo-bills 2019
# Starting buffalo-bills 2018
# Starting buffalo-bills 2017
# Starting carolina-panthers 2020
# Starting carolina-panthers 2019
# Starting carolina-panthers 2018
# Starting carolina-panthers 2017
# Starting chicago-bears 2020
# Starting chicago-bears 2019
# Starting chicago-bears 2018
# Starting chicago-bears 2017
# Starting cincinnati-bengals 2020
# Starting cincinnati-bengals 2019
# Starting cincinnati-bengals 2018
# Starting cincinnati-bengals 2017
# Starting cleveland-browns 2020
# Starting cleveland-browns 2019
# Starting cleveland-browns 2018
# Starting cleveland-browns 2017
# Starting dallas-cowboys 2020
# Starting dallas-cowboys 2019
# Starting dallas-cowboys 2018
# Starting dallas-cowboys 2017
# Starting denver-broncos 2020
# Starting denver-broncos 2019
# Starting denver-broncos 2018
# Starting denver-broncos 2017
# Starting detroit-lions 2020
# Starting detroit-lions 2019
# Starting detroit-lions 2018
# Starting detroit-lions 2017
# Starting green-bay-packers 2020
# Starting green-bay-packers 2019
# Starting green-bay-packers 2018
# Starting green-bay-packers 2017
# Starting houston-texans 2020
# Starting houston-texans 2019
# Starting houston-texans 2018
# Starting houston-texans 2017
# Starting indianapolis-colts 2020
# Starting indianapolis-colts 2019
# Starting indianapolis-colts 2018
# Starting indianapolis-colts 2017
# Starting jacksonville-jaguars 2020
# Starting jacksonville-jaguars 2019
# Starting jacksonville-jaguars 2018
# Starting jacksonville-jaguars 2017
# Starting kansas-city-chiefs 2020
# Starting kansas-city-chiefs 2019
# Starting kansas-city-chiefs 2018
# Starting kansas-city-chiefs 2017
# Starting las-vegas-raiders 2020
# Starting las-vegas-raiders 2019
# Starting las-vegas-raiders 2018
# Starting las-vegas-raiders 2017
# Starting los-angeles-chargers 2020
# Starting los-angeles-chargers 2019
# Starting los-angeles-chargers 2018
# Starting los-angeles-chargers 2017
# Starting los-angeles-rams 2020
# Starting los-angeles-rams 2019
# Starting los-angeles-rams 2018
# Starting los-angeles-rams 2017
# Starting miami-dolphins 2020
# Starting miami-dolphins 2019
# Starting miami-dolphins 2018
# Starting miami-dolphins 2017
# Starting minnesota-vikings 2020
# Starting minnesota-vikings 2019
# Starting minnesota-vikings 2018
# Starting minnesota-vikings 2017
# Starting new-england-patriots 2020
# Starting new-england-patriots 2019
# Starting new-england-patriots 2018
# Starting new-england-patriots 2017
# Starting new-orleans-saints 2020
# Starting new-orleans-saints 2019
# Starting new-orleans-saints 2018
# Starting new-orleans-saints 2017
# Starting new-york-giants 2020
# Starting new-york-giants 2019
# Starting new-york-giants 2018
# Starting new-york-giants 2017
# Starting new-york-jets 2020
# Starting new-york-jets 2019
# Starting new-york-jets 2018
# Starting new-york-jets 2017
# Starting philadelphia-eagles 2020
# Starting philadelphia-eagles 2019
# Starting philadelphia-eagles 2018
# Starting philadelphia-eagles 2017
# Starting pittsburgh-steelers 2020
# Starting pittsburgh-steelers 2019
# Starting pittsburgh-steelers 2018
# Starting pittsburgh-steelers 2017
# Starting san-francisco-49ers 2020
# Starting san-francisco-49ers 2019
# Starting san-francisco-49ers 2018
# Starting san-francisco-49ers 2017
# Starting seattle-seahawks 2020
# Starting seattle-seahawks 2019
# Starting seattle-seahawks 2018
# Starting seattle-seahawks 2017
# Starting tampa-bay-buccaneers 2020
# Starting tampa-bay-buccaneers 2019
# Starting tampa-bay-buccaneers 2018
# Starting tampa-bay-buccaneers 2017
# Starting tennessee-titans 2020
# Starting tennessee-titans 2019
# Starting tennessee-titans 2018
# Starting tennessee-titans 2017
# Starting washington-redskins 2020
# Starting washington-redskins 2019
# Starting washington-redskins 2018
# Starting washington-redskins 2017
# --- 5725.135033130646 seconds ---
#   Pos           Name Number Rating  Ranking Height Weight Age  Birthday Exp.  \
# 0  QB   Kyler Murray      1     77   #27 QB  5'10"    207  22    8/6/97    2
# 1  QB  Drew Anderson      3     70   #62 QB   6'4"    223  24  10/17/95    1
# 2  QB  Brett Hundley      7     67  #120 QB   6'3"    226  27   6/14/93    6
# 3  RB   Kenyan Drake     41     82   #36 RB   6'1"    210  26   1/25/94    5
# 4  RB  Chase Edmonds     29     74  #128 RB   5'9"    205  24   4/12/96    3
#
#   Drafted Draft Round Draft Pick       College  Merge Name               Team  \
# 0    2019           1          1      Oklahoma    K.Murray  Arizona Cardinals
# 1    2019                         Murray State  D.Anderson  Arizona Cardinals
# 2    2015           5        147          UCLA   B.Hundley  Arizona Cardinals
# 3    2016           3         73       Alabama     K.Drake  Arizona Cardinals
# 4    2018           4        134       Fordham   C.Edmonds  Arizona Cardinals
#
#    Year
# 0  2020
# 1  2020
# 2  2020
# 3  2020
# 4  2020
