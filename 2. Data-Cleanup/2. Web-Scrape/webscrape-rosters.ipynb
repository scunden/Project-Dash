# %% [markdown]
# # Web Scraping Positions

# %% [markdown]
# ## Setup Environment

# %%
import requests
import lxml.html as lh
import pandas as pd

# %% [markdown]
# ## Read Web Page

# %%
team = 'minnesota-vikings'
url='https://www.lineups.com/nfl/roster/'+team

#Create a handle, page, to handle the contents of the website
page = requests.get(url)

#Store the contents of the website under doc
doc = lh.fromstring(page.content)

# %%
[len(T) for T in tr_elements[:12]]
# Out:
# [14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]

# %%
#Parse data that are stored between <tr>..</tr> of HTMLtr_elements = doc.xpath('//tr')

#Create empty list
col = [(name.strip(),[])]

#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    name=t.text_content()
    col.append((name.strip(),[]))

# %%
col
# Out:
# [('Pos', []),
#  ('Name', []),
#  ('Number', []),
#  ('Rating', []),
#  ('Ranking', []),
#  ('Height', []),
#  ('Weight', []),
#  ('Age', []),
#  ('Birthday', []),
#  ('Exp.', []),
#  ('Drafted', []),
#  ('Draft Round', []),
#  ('Draft Pick', []),
#  ('College', [])]

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=14:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        data = str(data).strip()
        #Check if row is empty
#         if i>0:
#         #Convert any numerical value to integers
#             try:
#                 data=int(data)
#             except:
#                 pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
# [len(C) for (title,C) in col]

Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)
df['Name'] = df['Name'].str.split('\n').str[0].str.strip()
df['Name 2'] = df['Name'].str.split(' ').str[0].str[0] + '.' + df['Name'].str.split(' ').str[1]

df.head()
# Out:
#   Pos           Name Number Rating  Ranking Height Weight Age Birthday Exp.  \
# 0  QB   Kirk Cousins      8     82   #17 QB   6'3"    214  31  8/19/88    9
# 1  QB  Jake Browning      3     74   #39 QB   6'2"    211  24  4/11/96    1
# 2  QB   Nate Stanley      7     67  #120 QB   6'4"    235  22  8/26/97    0
# 3  QB   Sean Mannion      4     67  #120 QB   6'6"    229  28  4/25/92    6
# 4  RB    Dalvin Cook     33     90    #6 RB  5'10"    210  24  8/10/95    4
#
#   Drafted Draft Round Draft Pick         College      Name 2
# 0    2012           4        102  Michigan State   K.Cousins
# 1    2019                             Washington  J.Browning
# 2    2020           7        244            Iowa   N.Stanley
# 3    2015           3         89    Oregon State   S.Mannion
# 4    2017           2         41   Florida State      D.Cook

# %%
col
# Out:
# [('Pos',
#   ['QB',
#    'QB',
#    'QB',
#    'QB',
#    'RB',
#    'RB',
#    'RB',
#    'RB',
#    'RB',
#    'RB',
#    'RB',
#    'WR',
#    'WR',
#    'WR',
#    'WR',
#    'WR',
#    'WR',
#    'WR',
#    'WR',
#    'WR',
#    'WR',
#    'WR',
#    'TE',
#    'TE',
#    'TE',
#    'TE',
#    'TE',
#    'C',
#    'C',
#    'C',
#    'C',
#    'OG',
#    'OG',
#    'OG',
#    'OG',
#    'OT',
#    'OT',
#    'OT',
#    'OT',
#    'OT',
#    'OT',
#    'OT',
#    'OT',
#    'DT',
#    'DT',
#    'DT',
#    'DT',
#    'DT',
#    'DE',
#    'DE',
#    'DE',
#    'DE',
#    'DE',
#    'DE',
#    'LB',
#    'LB',
#    'LB',
#    'LB',
#    'LB',
#    'LB',
#    'LB',
#    'LB',
#    'LB',
#    'LB',
#    'LB',
#    'CB',
#    'CB',
#    'CB',
#    'CB',
#    'CB',
#    'CB',
#    'CB',
#    'CB',
#    'CB',
#    'CB',
#    'CB',
#    'SS',
#    'SS',
#    'SS',
#    'FS',
#    'FS',
#    'LS',
#    'P',
#    'PK']),
#  ('Name',
#   ['Kirk Cousins\n        \n        K. Cousins',
# ...
